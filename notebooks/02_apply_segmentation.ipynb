# %% [markdown]
# # 02 - Apply segmentation mask

# %% [markdown]
# ## Import dependences

# %%
import os
import sys

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

import torch
import torchvision
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from torchvision.models.detection.mask_rcnn import MaskRCNNPredictor
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import random
from tqdm import tqdm

from src.paths import ISIC_IMAGES_DIR, ISIC_MASKS_DIR, MODELS_DIR, SEGMENTATION_DIR
from src.viz import setup_style, save_fig

setup_style()

# %% [markdown]
# ## Define images path and masks path

# %%
ISIC_MASKS_DIR.mkdir(parents=True, exist_ok=True)
SEGMENTATION_DIR.mkdir(parents=True, exist_ok=True)

print(f"Source images: {ISIC_IMAGES_DIR}")
print(f"Output masks:  {ISIC_MASKS_DIR}")
print(f"Images on disk: {len(os.listdir(ISIC_IMAGES_DIR)):,}")

# %% [markdown]
# ## Define architecture model

# %%
def get_model(num_classes):
    # Load an instance segmentation model pre-trained on COCO
    model = torchvision.models.detection.maskrcnn_resnet50_fpn(pretrained=True) 

    # Replace the box predictor (FastRCNN)
    in_features = model.roi_heads.box_predictor.cls_score.in_features
    model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)

    # Replace the mask predictor (MaskRCNN)
    in_features_mask = model.roi_heads.mask_predictor.conv5_mask.in_channels
    hidden_layer = 256
    model.roi_heads.mask_predictor = MaskRCNNPredictor(in_features_mask,
                                                       hidden_layer,
                                                       num_classes)
    return model

# %% [markdown]
# ## Load trained weights

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
print(f"Device: {device}")

model_path = MODELS_DIR / 'maskrcnn_ham10000.pth'
model = get_model(num_classes=2)
model.load_state_dict(torch.load(model_path, map_location=device))
model.to(device)
model.eval()
print(f"Loaded {model_path}")

# %% [markdown]
# ## Apply and save masks

# %%
mask_threshold = 0.5

for img_name in tqdm(os.listdir(ISIC_IMAGES_DIR), desc="Processing images"):
    if not img_name.lower().endswith(('.jpg', '.jpeg', '.png')):
        continue

    img_path = ISIC_IMAGES_DIR / img_name
    image = Image.open(img_path).convert("RGB")
    image_tensor = torchvision.transforms.functional.to_tensor(image).to(device)

    with torch.no_grad():
        prediction = model([image_tensor])

    if len(prediction[0]['masks']) > 0:
        raw_mask = prediction[0]['masks'][0, 0]
        binary_mask = raw_mask > mask_threshold
        mask_arr = binary_mask.mul(255).byte().cpu().numpy()
        mask_image = Image.fromarray(mask_arr).convert('L')
    else:
        mask_image = Image.new('L', image.size, 0)

    # Same filename as input — downstream code in notebook 03 expects this.
    mask_image.save(ISIC_MASKS_DIR / img_name)

# %% [markdown]
# ## Visual validation grid
#
# Quick sanity check: render 9 random (image, predicted-mask) pairs as a single PNG so we can eyeball segmentation quality on the VM without downloading the 75k mask files.

# %%
mask_files = [
    f for f in os.listdir(ISIC_MASKS_DIR)
    if f.lower().endswith(('.jpg', '.jpeg', '.png'))
]
random.seed(0)
sample = random.sample(mask_files, min(9, len(mask_files)))

fig, axes = plt.subplots(3, 3, figsize=(15, 15))
fig.suptitle('ISIC — Predicted segmentation samples (n=9)', y=0.92)

for ax, fname in zip(axes.flat, sample):
    img = np.array(Image.open(ISIC_IMAGES_DIR / fname).convert('RGB'))
    mask = np.array(Image.open(ISIC_MASKS_DIR / fname).convert('L'))

    ax.imshow(img)
    ax.imshow(mask, alpha=0.45, cmap='Reds')
    ax.set_title(fname, fontsize=8)
    ax.axis('off')

plt.tight_layout()
save_fig(fig, SEGMENTATION_DIR, 'sample_predictions')
plt.show()
